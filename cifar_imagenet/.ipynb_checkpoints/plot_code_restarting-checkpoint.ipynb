# %%
import os

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
 
import seaborn as sns
import json
import pandas as pd

from IPython.core.debugger import Tracer

# %%
def make_dataframe(filename, trial_id, stride = 1, stop_point=500):
    with open(filename) as jfile:
        dat = json.load(jfile)
    for i in range(len(dat)):
        dat[i] = [trial_id] + dat[i]
    stop_point = min(stop_point, len(dat)-5)
    dat = dat[:stop_point:stride]
    df = pd.DataFrame(dat, columns=['trial_id','wall_time', 'step', 'value'])
    return df

# %%
###############################################################
#### Epoch time for unconditional FFJORD on CIFAR10 ####
###############################################################

save_dir = './figures'
save_name = 'train_loss_preact1001_cifar10_published.pdf'

#sgd
sgd = ['./data4plots/run-preresnet1001-sgd-0_train_loss_preresnet20_srsgd-tag-train_loss.json',
                        './data4plots/run-preresnet1001-sgd-1_train_loss_preresnet20_srsgd-tag-train_loss.json',
                        './data4plots/run-preresnet1001-sgd-2_train_loss_preresnet20_srsgd-tag-train_loss.json',
                        './data4plots/run-preresnet1001-sgd-3_train_loss_preresnet20_srsgd-tag-train_loss.json',
                        './data4plots/run-preresnet1001-sgd-4_train_loss_preresnet20_srsgd-tag-train_loss.json']
keys_sgd = ['run0','run1','run2', 'run3','run4']
id_sgd = 'SGD'
stop_point_sgd = 197

# srsgd
srsgd = ['./data4plots/run-preresnet1001-srsgd-0_train_loss_preresnet20_srsgd-tag-train_loss.json',
                        './data4plots/run-preresnet1001-srsgd-1_train_loss_preresnet20_srsgd-tag-train_loss.json',
                        './data4plots/run-preresnet1001-srsgd-2_train_loss_preresnet20_srsgd-tag-train_loss.json',
                        './data4plots/run-preresnet1001-srsgd-3_train_loss_preresnet20_srsgd-tag-train_loss.json',
                        './data4plots/run-preresnet1001-srsgd-4_train_loss_preresnet20_srsgd-tag-train_loss.json']
keys_srsgd = ['run0','run1','run2', 'run3','run4']
id_srsgd = 'SRSGD'
stop_point_srsgd = 197

# %%
sns.set(style="white")
def plot_line(file_names, keys, trial_id, stride=1, stop_point=500, color=None):
    df = []
    df_min = []
    for fn in file_names:
        df.append(make_dataframe(fn, trial_id, stride, stop_point=stop_point))
        stop_indx = min(90, len(df[-1]['value']))
        df_min.append(min(df[-1]['value'][:stop_indx]))
        # print(np.argmin(df[-1]['value'][:stop_indx]))
    df = pd.concat(df, keys=keys)
    sns_plot = sns.lineplot(x="step", y="value", data=df, color=color, linewidth=3, markersize=8)
    return sns_plot, df_min

# sns_plot, df_min_ccnf = plot_line(file_names_ccnf_bs900, keys_ccnf_bs900, id_ccnf_bs900, stride=10, stop_point=stop_point_ccnf_bs900, color='red')
# sns_plot, df_min_info = plot_line(file_names_info_bs900, keys_info_bs900, id_info_bs900, stride=10, stop_point=stop_point_info_bs900, color='green')
sns_plot, min_sgd = plot_line(sgd, keys_sgd, id_sgd, stride=1, stop_point=stop_point_sgd, color='red')
sns_plot, min_srsgd = plot_line(srsgd, keys_srsgd, id_srsgd, stride=1, stop_point=stop_point_srsgd, color='blue')
#sns_plot, df_min_infotune = plot_line(file_names_infotune_bs900, keys_infotune_bs900, id_infotune_bs900, stride=10, stop_point=stop_point_infotune_bs900, color='orange')

print('sgd')
print(np.mean(min_sgd))
print(np.std(min_sgd))

print('srsgd')
print(np.mean(min_srsgd))
print(np.std(min_srsgd))

sns_plot.set_xlabel('', fontsize = 16)
sns_plot.set_ylabel('', fontsize = 16)
sns_plot.set(yscale="log")
sns_plot.grid()
sns_plot.tick_params(axis='both', which='major', labelsize=15)
sns_plot.tick_params(axis='both', which='minor', labelsize=15)
# sns_plot.set(xscale="log", yscale="log")
#sns_plot.set_xlim(0,380)
#sns_plot.set_ylim(0.2,0.6)
#sns_plot.legend().set_visible(True)

fig = sns_plot.get_figure()
fig.savefig(os.path.join(save_dir, save_name))
# Out:
# sgd
# 0.09599025249481201
# 0.0008253471375479376
# srsgd
# 0.0567499577999115
# 0.0012703324561823789

# %%
###############################################################
#### Epoch time for unconditional FFJORD on CIFAR10 ####
###############################################################

save_dir = './figures'
save_name = 'train_loss_resnet200_imagenet_published.pdf'

#sgd
sgd = ['./data4plots/run-imagenet_resnet200_basline_sgd_lmdb_0_train_loss_resnet200_srsgd-tag-train_loss.json',]
keys_sgd = ['run0',]
id_sgd = 'SGD'
stop_point_sgd = 84

# srsgd
srsgd = ['./data4plots/run-imagenet_resnet200_lin_40_3rd_lineardecay_k_2_srsgd_0_train_loss_resnet200_srsgd-tag-train_loss.json',]
keys_srsgd = ['run0',]
id_srsgd = 'SRSGD'
stop_point_srsgd = 84

# %%
sns.set(style="white")
def plot_line(file_names, keys, trial_id, stride=1, stop_point=500, color=None):
    df = []
    df_min = []
    for fn in file_names:
        df.append(make_dataframe(fn, trial_id, stride, stop_point=stop_point))
        stop_indx = min(90, len(df[-1]['value']))
        df_min.append(min(df[-1]['value'][:stop_indx]))
        # print(np.argmin(df[-1]['value'][:stop_indx]))
    df = pd.concat(df, keys=keys)
    sns_plot = sns.lineplot(x="step", y="value", data=df, color=color, linewidth=3, markersize=8)
    return sns_plot, df_min

# sns_plot, df_min_ccnf = plot_line(file_names_ccnf_bs900, keys_ccnf_bs900, id_ccnf_bs900, stride=10, stop_point=stop_point_ccnf_bs900, color='red')
# sns_plot, df_min_info = plot_line(file_names_info_bs900, keys_info_bs900, id_info_bs900, stride=10, stop_point=stop_point_info_bs900, color='green')
sns_plot, min_sgd = plot_line(sgd, keys_sgd, id_sgd, stride=1, stop_point=stop_point_sgd, color='red')
sns_plot, min_srsgd = plot_line(srsgd, keys_srsgd, id_srsgd, stride=1, stop_point=stop_point_srsgd, color='blue')
#sns_plot, df_min_infotune = plot_line(file_names_infotune_bs900, keys_infotune_bs900, id_infotune_bs900, stride=10, stop_point=stop_point_infotune_bs900, color='orange')

print('sgd')
print(np.mean(min_sgd))
print(np.std(min_sgd))

print('srsgd')
print(np.mean(min_srsgd))
print(np.std(min_srsgd))

sns_plot.set_xlabel('', fontsize = 16)
sns_plot.set_ylabel('', fontsize = 16)
sns_plot.set(yscale="log")
sns_plot.grid()
sns_plot.tick_params(axis='both', which='major', labelsize=15)
sns_plot.tick_params(axis='both', which='minor', labelsize=15)
# sns_plot.set(xscale="log", yscale="log")
#sns_plot.set_xlim(0,380)
#sns_plot.set_ylim(0.2,0.6)
#sns_plot.legend().set_visible(True)

fig = sns_plot.get_figure()
fig.savefig(os.path.join(save_dir, save_name))
# Out:
# sgd
# 0.8505367040634155
# 0.0
# srsgd
# 0.8149948120117188
# 0.0

# %%
###############################################################
#### Epoch time for unconditional FFJORD on CIFAR10 ####
###############################################################

save_dir = './figures'
save_name = 'train_loss_resnet152_imagenet_published.pdf'

#sgd
sgd = ['./data4plots/run-imagenet_resnet152_basline_sgd_lmdb_0_train_loss_resnet152_srsgd-tag-train_loss.json',]
keys_sgd = ['run0',]
id_sgd = 'SGD'
stop_point_sgd = 72

# srsgd
srsgd = ['./data4plots/run-imagenet_resnet152_lin_40_3rd_lineardecay_k_1_5_srsgd_0_train_loss_resnet152_srsgd-tag-train_loss.json',]
keys_srsgd = ['run0',]
id_srsgd = 'SRSGD'
stop_point_srsgd = 72

# %%
sns.set(style="white")
def plot_line(file_names, keys, trial_id, stride=1, stop_point=500, color=None):
    df = []
    df_min = []
    for fn in file_names:
        df.append(make_dataframe(fn, trial_id, stride, stop_point=stop_point))
        stop_indx = min(90, len(df[-1]['value']))
        df_min.append(min(df[-1]['value'][:stop_indx]))
        # print(np.argmin(df[-1]['value'][:stop_indx]))
    df = pd.concat(df, keys=keys)
    sns_plot = sns.lineplot(x="step", y="value", data=df, color=color, linewidth=3, markersize=8)
    return sns_plot, df_min

# sns_plot, df_min_ccnf = plot_line(file_names_ccnf_bs900, keys_ccnf_bs900, id_ccnf_bs900, stride=10, stop_point=stop_point_ccnf_bs900, color='red')
# sns_plot, df_min_info = plot_line(file_names_info_bs900, keys_info_bs900, id_info_bs900, stride=10, stop_point=stop_point_info_bs900, color='green')
sns_plot, min_sgd = plot_line(sgd, keys_sgd, id_sgd, stride=1, stop_point=stop_point_sgd, color='red')
sns_plot, min_srsgd = plot_line(srsgd, keys_srsgd, id_srsgd, stride=1, stop_point=stop_point_srsgd, color='blue')
#sns_plot, df_min_infotune = plot_line(file_names_infotune_bs900, keys_infotune_bs900, id_infotune_bs900, stride=10, stop_point=stop_point_infotune_bs900, color='orange')

print('sgd')
print(np.mean(min_sgd))
print(np.std(min_sgd))

print('srsgd')
print(np.mean(min_srsgd))
print(np.std(min_srsgd))

sns_plot.set_xlabel('', fontsize = 16)
sns_plot.set_ylabel('', fontsize = 16)
sns_plot.set(yscale="log")
sns_plot.grid()
sns_plot.tick_params(axis='both', which='major', labelsize=15)
sns_plot.tick_params(axis='both', which='minor', labelsize=15)
# sns_plot.set(xscale="log", yscale="log")
#sns_plot.set_xlim(0,380)
#sns_plot.set_ylim(0.2,0.6)
#sns_plot.legend().set_visible(True)

fig = sns_plot.get_figure()
fig.savefig(os.path.join(save_dir, save_name))
# Out:
# sgd
# 0.9042623043060303
# 0.0
# srsgd
# 0.8625646829605103
# 0.0

# %%
###############################################################
#### Epoch time for unconditional FFJORD on CIFAR10 ####
###############################################################

save_dir = './figures'
save_name = 'test_loss_preact1001_cifar10_published.pdf'

#sgd
sgd = ['./data4plots/run-preresnet1001-sgd-0_test_loss_preresnet20_srsgd-tag-test_loss.json',
                        './data4plots/run-preresnet1001-sgd-1_test_loss_preresnet20_srsgd-tag-test_loss.json',
                        './data4plots/run-preresnet1001-sgd-2_test_loss_preresnet20_srsgd-tag-test_loss.json',
                        './data4plots/run-preresnet1001-sgd-3_test_loss_preresnet20_srsgd-tag-test_loss.json',
                        './data4plots/run-preresnet1001-sgd-4_test_loss_preresnet20_srsgd-tag-test_loss.json']
keys_sgd = ['run0','run1','run2', 'run3','run4']
id_sgd = 'SGD'
stop_point_sgd = 197

# srsgd
srsgd = ['./data4plots/run-preresnet1001-srsgd-0_test_loss_preresnet20_srsgd-tag-test_loss.json',
                        './data4plots/run-preresnet1001-srsgd-1_test_loss_preresnet20_srsgd-tag-test_loss.json',
                        './data4plots/run-preresnet1001-srsgd-2_test_loss_preresnet20_srsgd-tag-test_loss.json',
                        './data4plots/run-preresnet1001-srsgd-3_test_loss_preresnet20_srsgd-tag-test_loss.json',
                        './data4plots/run-preresnet1001-srsgd-4_test_loss_preresnet20_srsgd-tag-test_loss.json']
keys_srsgd = ['run0','run1','run2', 'run3','run4']
id_srsgd = 'SRSGD'
stop_point_srsgd = 197

# %%
sns.set(style="white")
def plot_line(file_names, keys, trial_id, stride=1, stop_point=500, color=None):
    df = []
    df_min = []
    for fn in file_names:
        df.append(make_dataframe(fn, trial_id, stride, stop_point=stop_point))
        stop_indx = min(90, len(df[-1]['value']))
        df_min.append(min(df[-1]['value'][:stop_indx]))
        # print(np.argmin(df[-1]['value'][:stop_indx]))
    df = pd.concat(df, keys=keys)
    sns_plot = sns.lineplot(x="step", y="value", data=df, color=color, linewidth=3, markersize=8)
    return sns_plot, df_min

# sns_plot, df_min_ccnf = plot_line(file_names_ccnf_bs900, keys_ccnf_bs900, id_ccnf_bs900, stride=10, stop_point=stop_point_ccnf_bs900, color='red')
# sns_plot, df_min_info = plot_line(file_names_info_bs900, keys_info_bs900, id_info_bs900, stride=10, stop_point=stop_point_info_bs900, color='green')
sns_plot, min_sgd = plot_line(sgd, keys_sgd, id_sgd, stride=1, stop_point=stop_point_sgd, color='red')
sns_plot, min_srsgd = plot_line(srsgd, keys_srsgd, id_srsgd, stride=1, stop_point=stop_point_srsgd, color='blue')
#sns_plot, df_min_infotune = plot_line(file_names_infotune_bs900, keys_infotune_bs900, id_infotune_bs900, stride=10, stop_point=stop_point_infotune_bs900, color='orange')

print('sgd')
print(np.mean(min_sgd))
print(np.std(min_sgd))

print('srsgd')
print(np.mean(min_srsgd))
print(np.std(min_srsgd))

sns_plot.set_xlabel('', fontsize = 16)
sns_plot.set_ylabel('', fontsize = 16)
sns_plot.set(yscale="log")
sns_plot.grid()
sns_plot.tick_params(axis='both', which='major', labelsize=15)
sns_plot.tick_params(axis='both', which='minor', labelsize=15)
# sns_plot.set(xscale="log", yscale="log")
#sns_plot.set_xlim(0,380)
#sns_plot.set_ylim(0.2,0.6)
#sns_plot.legend().set_visible(True)

fig = sns_plot.get_figure()
fig.savefig(os.path.join(save_dir, save_name))
# Out:
# sgd
# 0.19179794788360596
# 0.004501442035629221
# srsgd
# 0.1573304384946823
# 0.0030246000623244222

# %%
save_dir = './figures'
save_name = 'test_loss_resnet152_imagenet_published.pdf'

#sgd
sgd = ['./data4plots/run-imagenet_resnet152_basline_sgd_lmdb_0_test_loss_resnet152_srsgd-tag-test_loss.json',]
keys_sgd = ['run0',]
id_sgd = 'SGD'
stop_point_sgd = 72

# srsgd
srsgd = ['./data4plots/run-imagenet_resnet152_lin_40_3rd_lineardecay_k_1_5_srsgd_0_test_loss_resnet152_srsgd-tag-test_loss.json',]
keys_srsgd = ['run0',]
id_srsgd = 'SRSGD'
stop_point_srsgd = 72

# %%
sns.set(style="white")
def plot_line(file_names, keys, trial_id, stride=1, stop_point=500, color=None):
    df = []
    df_min = []
    for fn in file_names:
        df.append(make_dataframe(fn, trial_id, stride, stop_point=stop_point))
        stop_indx = min(90, len(df[-1]['value']))
        df_min.append(min(df[-1]['value'][:stop_indx]))
        # print(np.argmin(df[-1]['value'][:stop_indx]))
    df = pd.concat(df, keys=keys)
    sns_plot = sns.lineplot(x="step", y="value", data=df, color=color, linewidth=3, markersize=8)
    return sns_plot, df_min

# sns_plot, df_min_ccnf = plot_line(file_names_ccnf_bs900, keys_ccnf_bs900, id_ccnf_bs900, stride=10, stop_point=stop_point_ccnf_bs900, color='red')
# sns_plot, df_min_info = plot_line(file_names_info_bs900, keys_info_bs900, id_info_bs900, stride=10, stop_point=stop_point_info_bs900, color='green')
sns_plot, min_sgd = plot_line(sgd, keys_sgd, id_sgd, stride=1, stop_point=stop_point_sgd, color='red')
sns_plot, min_srsgd = plot_line(srsgd, keys_srsgd, id_srsgd, stride=1, stop_point=stop_point_srsgd, color='blue')
#sns_plot, df_min_infotune = plot_line(file_names_infotune_bs900, keys_infotune_bs900, id_infotune_bs900, stride=10, stop_point=stop_point_infotune_bs900, color='orange')

print('sgd')
print(np.mean(min_sgd))
print(np.std(min_sgd))

print('srsgd')
print(np.mean(min_srsgd))
print(np.std(min_srsgd))

sns_plot.set_xlabel('', fontsize = 16)
sns_plot.set_ylabel('', fontsize = 16)
sns_plot.set(yscale="log")
sns_plot.grid()
sns_plot.tick_params(axis='both', which='major', labelsize=15)
sns_plot.tick_params(axis='both', which='minor', labelsize=15)
# sns_plot.set(xscale="log", yscale="log")
#sns_plot.set_xlim(0,380)
#sns_plot.set_ylim(0.2,0.6)
#sns_plot.legend().set_visible(True)

fig = sns_plot.get_figure()
fig.savefig(os.path.join(save_dir, save_name))
# Out:
# sgd
# 0.8855056762695312
# 0.0
# srsgd
# 0.8723387718200684
# 0.0

# %%
save_dir = './figures'
save_name = 'test_loss_resnet200_imagenet_published.pdf'

#sgd
sgd = ['./data4plots/run-imagenet_resnet200_basline_sgd_lmdb_0_test_loss_resnet200_srsgd-tag-test_loss.json',]
keys_sgd = ['run0',]
id_sgd = 'SGD'
stop_point_sgd = 84

# srsgd
srsgd = ['./data4plots/run-imagenet_resnet200_lin_40_3rd_lineardecay_k_2_srsgd_0_test_loss_resnet200_srsgd-tag-test_loss.json',]
keys_srsgd = ['run0',]
id_srsgd = 'SRSGD'
stop_point_srsgd = 84

# %%
sns.set(style="white")
def plot_line(file_names, keys, trial_id, stride=1, stop_point=500, color=None):
    df = []
    df_min = []
    for fn in file_names:
        df.append(make_dataframe(fn, trial_id, stride, stop_point=stop_point))
        stop_indx = min(90, len(df[-1]['value']))
        df_min.append(min(df[-1]['value'][:stop_indx]))
        # print(np.argmin(df[-1]['value'][:stop_indx]))
    df = pd.concat(df, keys=keys)
    sns_plot = sns.lineplot(x="step", y="value", data=df, color=color, linewidth=3, markersize=8)
    return sns_plot, df_min

# sns_plot, df_min_ccnf = plot_line(file_names_ccnf_bs900, keys_ccnf_bs900, id_ccnf_bs900, stride=10, stop_point=stop_point_ccnf_bs900, color='red')
# sns_plot, df_min_info = plot_line(file_names_info_bs900, keys_info_bs900, id_info_bs900, stride=10, stop_point=stop_point_info_bs900, color='green')
sns_plot, min_sgd = plot_line(sgd, keys_sgd, id_sgd, stride=1, stop_point=stop_point_sgd, color='red')
sns_plot, min_srsgd = plot_line(srsgd, keys_srsgd, id_srsgd, stride=1, stop_point=stop_point_srsgd, color='blue')
#sns_plot, df_min_infotune = plot_line(file_names_infotune_bs900, keys_infotune_bs900, id_infotune_bs900, stride=10, stop_point=stop_point_infotune_bs900, color='orange')

print('sgd')
print(np.mean(min_sgd))
print(np.std(min_sgd))

print('srsgd')
print(np.mean(min_srsgd))
print(np.std(min_srsgd))

sns_plot.set_xlabel('', fontsize = 16)
sns_plot.set_ylabel('', fontsize = 16)
sns_plot.set(yscale="log")
sns_plot.grid()
sns_plot.tick_params(axis='both', which='major', labelsize=15)
sns_plot.tick_params(axis='both', which='minor', labelsize=15)
# sns_plot.set(xscale="log", yscale="log")
#sns_plot.set_xlim(0,380)
#sns_plot.set_ylim(0.2,0.6)
#sns_plot.legend().set_visible(True)

fig = sns_plot.get_figure()
fig.savefig(os.path.join(save_dir, save_name))
# Out:
# sgd
# 0.8816143870353699
# 0.0
# srsgd
# 0.8383951783180237
# 0.0

# %%
###############################################################
#### Epoch time for unconditional FFJORD on CIFAR10 ####
###############################################################

save_dir = './figures'
save_name = 'train_loss_vs_f_preresnet290_cifar10_published.pdf'

keys = ['run0',]
stop_point = 200
#srsgd
f1 = ['./data4plots/run-preresnet290-n-1_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id1 = 'F1=1'

f2 = ['./data4plots/run-preresnet290-n-2_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id2 = 'F1=2'

f5 = ['./data4plots/run-preresnet290-n-5_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id5 = 'F1=5'

f7 = ['./data4plots/run-preresnet290-n-7_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id7 = 'F1=7'

f10 = ['./data4plots/run-preresnet290-n-10_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id10 = 'F1=10'

f20 = ['./data4plots/run-preresnet290-n-20_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id20 = 'F1=20'

f30 = ['./data4plots/run-preresnet290-n-30_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id30 = 'F1=30'

f40 = ['./data4plots/run-preresnet290-n-40_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id40 = 'F1=40'

f50 = ['./data4plots/run-preresnet290-n-50_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id50 = 'F1=50'

f60 = ['./data4plots/run-preresnet290-n-60_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id60 = 'F1=60'

f70 = ['./data4plots/run-preresnet290-n-70_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id70 = 'F1=70'

f80 = ['./data4plots/run-preresnet290-n-80_train_loss_preresnet20_srsgd-tag-train_loss.json',]
id80 = 'F1=80'

# %%
sns.set(style="white")
def plot_line(file_names, keys, trial_id, stride=1, stop_point=500, color=None, linewidth=1, alpha=1.0):
    df = []
    df_min = []
    for fn in file_names:
        df.append(make_dataframe(fn, trial_id, stride, stop_point=stop_point))
        stop_indx = min(200, len(df[-1]['value']))
        df_min.append(min(df[-1]['value'][:stop_indx]))
        # print(np.argmin(df[-1]['value'][:stop_indx]))
    df = pd.concat(df, keys=keys)
    sns_plot = sns.lineplot(x="step", y="value", data=df, color=color, linewidth=linewidth, markersize=8, label=trial_id, alpha=alpha)
    return sns_plot, df_min

sns_plot, _ = plot_line(f1, keys, id1, stride=1, stop_point=stop_point, color='green', linewidth=3, alpha=1.0)
#sns_plot, _ = plot_line(f2, keys, id2, stride=1, stop_point=stop_point, color='xkcd:sky blue')
sns_plot, _ = plot_line(f5, keys, id5, stride=1, stop_point=stop_point, color='tab:cyan', linewidth=1, alpha=0.7)
#sns_plot, _ = plot_line(f7, keys, id7, stride=1, stop_point=stop_point, color='tab:pink')
sns_plot, _ = plot_line(f10, keys, id10, stride=1, stop_point=stop_point, color='tab:orange', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f20, keys, id20, stride=1, stop_point=stop_point, color='red', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f30, keys, id30, stride=1, stop_point=stop_point, color='blue', linewidth=3, alpha=1.0)
sns_plot, _ = plot_line(f40, keys, id40, stride=1, stop_point=stop_point, color='tab:purple', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f50, keys, id50, stride=1, stop_point=stop_point, color='magenta', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f60, keys, id60, stride=1, stop_point=stop_point, color='tab:brown', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f70, keys, id70, stride=1, stop_point=stop_point, color='black', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f80, keys, id80, stride=1, stop_point=stop_point, color='tab:olive', linewidth=3, alpha=1.0)


sns_plot.set_xlabel('', fontsize = 16)
sns_plot.set_ylabel('', fontsize = 16)
sns_plot.set(yscale="log")
sns_plot.grid()
sns_plot.tick_params(axis='both', which='major', labelsize=15)
sns_plot.tick_params(axis='both', which='minor', labelsize=15)
#sns_plot.set(xscale="log", yscale="log")
sns_plot.set_xlim(right=214)
#sns_plot.set_ylim(bottom=0.002)
sns_plot.legend().set_visible(True)

fig = sns_plot.get_figure()
fig.savefig(os.path.join(save_dir, save_name))

# %%
###############################################################
#### Epoch time for unconditional FFJORD on CIFAR10 ####
###############################################################

save_dir = './figures'
save_name = 'test_error_vs_f_preresnet290_cifar10_published.pdf'

keys = ['run0',]
stop_point = 200
#srsgd
f10 = ['./data4plots/run-preresnet290-n-10_test_acc_preresnet20_srsgd-tag-test_acc.json',]
id10 = 'F=10'

f20 = ['./data4plots/run-preresnet290-n-20_test_acc_preresnet20_srsgd-tag-test_acc.json',]
id20 = 'F=20'

f30 = ['./data4plots/run-preresnet290-n-30_test_acc_preresnet20_srsgd-tag-test_acc.json',]
id30 = 'F=30'

f40 = ['./data4plots/run-preresnet290-n-40_test_acc_preresnet20_srsgd-tag-test_acc.json',]
id40 = 'F=40'

f50 = ['./data4plots/run-preresnet290-n-50_test_acc_preresnet20_srsgd-tag-test_acc.json',]
id50 = 'F=50'

f60 = ['./data4plots/run-preresnet290-n-60_test_acc_preresnet20_srsgd-tag-test_acc.json',]
id60 = 'F=60'

f70 = ['./data4plots/run-preresnet290-n-70_test_acc_preresnet20_srsgd-tag-test_acc.json',]
id70 = 'F=70'

f80 = ['./data4plots/run-preresnet290-n-80_test_acc_preresnet20_srsgd-tag-test_acc.json',]
id80 = 'F=80'

# %%
sns.set(style="white")
def plot_line(file_names, keys, trial_id, stride=1, stop_point=500, color=None):
    df = []
    df_min = []
    for fn in file_names:
        df.append(make_dataframe(fn, trial_id, stride, stop_point=stop_point))
        df[-1]['value'] = 100 - df[-1]['value']
        stop_indx = min(200, len(df[-1]['value']))
        df_min.append(min(df[-1]['value'][:stop_indx]))
        # print(np.argmin(df[-1]['value'][:stop_indx]))
    df = pd.concat(df, keys=keys)
    sns_plot = sns.lineplot(x="step", y="value", data=df, color=color, linewidth=3, markersize=8, label=trial_id)
    return sns_plot, df_min


sns_plot, _ = plot_line(f10, keys, id10, stride=1, stop_point=stop_point, color='blue')
sns_plot, _ = plot_line(f20, keys, id20, stride=1, stop_point=stop_point, color='green')
sns_plot, _ = plot_line(f30, keys, id30, stride=1, stop_point=stop_point, color='red')
sns_plot, _ = plot_line(f40, keys, id40, stride=1, stop_point=stop_point, color='tab:purple')
sns_plot, _ = plot_line(f50, keys, id50, stride=1, stop_point=stop_point, color='magenta')
sns_plot, _ = plot_line(f60, keys, id60, stride=1, stop_point=stop_point, color='yellow')
sns_plot, _ = plot_line(f70, keys, id70, stride=1, stop_point=stop_point, color='black')
sns_plot, _ = plot_line(f80, keys, id80, stride=1, stop_point=stop_point, color='tab:orange')


sns_plot.set_xlabel('', fontsize = 16)
sns_plot.set_ylabel('', fontsize = 16)
sns_plot.set(yscale="log")
sns_plot.grid()
sns_plot.tick_params(axis='both', which='major', labelsize=15)
sns_plot.tick_params(axis='both', which='minor', labelsize=15)
sns_plot.set(xscale="log", yscale="log")
#sns_plot.set_xlim(0,380)
#sns_plot.set_ylim(0.2,0.6)
sns_plot.legend().set_visible(True)

fig = sns_plot.get_figure()
fig.savefig(os.path.join(save_dir, save_name))

# %%
###############################################################
#### Epoch time for unconditional FFJORD on CIFAR10 ####
###############################################################

save_dir = './figures'
save_name = 'train_loss_vs_f_resnet101_imagenet_published.pdf'

keys = ['run0',]
stop_point = 89
#srsgd
f1 = ['./data4plots/run-resnet101-n-1_train_loss_resnet101_srsgd-tag-train_loss.json',]
id1 = 'F1=1'

f5 = ['./data4plots/run-resnet101-n-5_train_loss_resnet101_srsgd-tag-train_loss.json',]
id5 = 'F1=5'

f20 = ['./data4plots/run-resnet101-n-20_train_loss_resnet101_srsgd-tag-train_loss.json',]
id20 = 'F1=20'

f40 = ['./data4plots/run-resnet101-n-40_train_loss_resnet101_srsgd-tag-train_loss.json',]
id40 = 'F1=40'

f60 = ['./data4plots/run-resnet101-n-60_train_loss_resnet101_srsgd-tag-train_loss.json',]
id60 = 'F1=60'

f80 = ['./data4plots/run-resnet101-n-80_train_loss_resnet101_srsgd-tag-train_loss.json',]
id80 = 'F1=80'

f100 = ['./data4plots/run-resnet101-n-100_train_loss_resnet101_srsgd-tag-train_loss.json',]
id100 = 'F1=100'

# %%
sns.set(style="white")
def plot_line(file_names, keys, trial_id, stride=1, stop_point=500, color=None, linewidth=1, alpha=1.0):
    df = []
    df_min = []
    for fn in file_names:
        df.append(make_dataframe(fn, trial_id, stride, stop_point=stop_point))
        stop_indx = min(89, len(df[-1]['value']))
        df_min.append(min(df[-1]['value'][:stop_indx]))
        # print(np.argmin(df[-1]['value'][:stop_indx]))
    df = pd.concat(df, keys=keys)
    sns_plot = sns.lineplot(x="step", y="value", data=df, color=color, linewidth=linewidth, markersize=8, label=trial_id, alpha=alpha)
    return sns_plot, df_min

sns_plot, _ = plot_line(f1, keys, id1, stride=1, stop_point=stop_point, color='green', linewidth=3, alpha=1.0)
sns_plot, _ = plot_line(f5, keys, id5, stride=1, stop_point=stop_point, color='tab:cyan', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f20, keys, id20, stride=1, stop_point=stop_point, color='red', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f40, keys, id40, stride=1, stop_point=stop_point, color='blue', linewidth=3, alpha=1.0)
sns_plot, _ = plot_line(f60, keys, id60, stride=1, stop_point=stop_point, color='magenta', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f80, keys, id80, stride=1, stop_point=stop_point, color='tab:orange', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f100, keys, id100, stride=1, stop_point=stop_point, color='tab:olive', linewidth=3, alpha=1.0)


sns_plot.set_xlabel('', fontsize = 16)
sns_plot.set_ylabel('', fontsize = 16)
sns_plot.set(yscale="log")
sns_plot.grid()
sns_plot.tick_params(axis='both', which='major', labelsize=15)
sns_plot.tick_params(axis='both', which='minor', labelsize=15)
#sns_plot.set(xscale="log", yscale="log")
sns_plot.set_xlim(right=89)
#sns_plot.set_ylim(bottom=0.002)
sns_plot.legend().set_visible(True)

fig = sns_plot.get_figure()
fig.savefig(os.path.join(save_dir, save_name))

# %%
###############################################################
#### Epoch time for unconditional FFJORD on CIFAR10 ####
###############################################################

save_dir = './figures'
save_name = 'train_loss_vs_f_preresnet290_cifar100_published.pdf'

keys = ['run0',]
stop_point = 200
#srsgd
f1 = ['./data4plots/run-preresnet290-n-1_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id1 = 'F1=1'

f2 = ['./data4plots/run-preresnet290-n-2_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id2 = 'F1=2'

f5 = ['./data4plots/run-preresnet290-n-5_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id5 = 'F1=5'

f7 = ['./data4plots/run-preresnet290-n-7_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id7 = 'F1=7'

f10 = ['./data4plots/run-preresnet290-n-10_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id10 = 'F1=10'

f20 = ['./data4plots/run-preresnet290-n-20_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id20 = 'F1=20'

f30 = ['./data4plots/run-preresnet290-n-30_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id30 = 'F1=30'

f40 = ['./data4plots/run-preresnet290-n-40_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id40 = 'F1=40'

f50 = ['./data4plots/run-preresnet290-n-50_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id50 = 'F1=50'

f60 = ['./data4plots/run-preresnet290-n-60_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id60 = 'F1=60'

f70 = ['./data4plots/run-preresnet290-n-70_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id70 = 'F1=70'

f80 = ['./data4plots/run-preresnet290-n-80_train_loss_preresnet20_srsgd-tag-train_loss_cifar100.json',]
id80 = 'F1=80'

# %%
sns.set(style="white")
def plot_line(file_names, keys, trial_id, stride=1, stop_point=500, color=None, linewidth=1, alpha=1.0):
    df = []
    df_min = []
    for fn in file_names:
        df.append(make_dataframe(fn, trial_id, stride, stop_point=stop_point))
        stop_indx = min(200, len(df[-1]['value']))
        df_min.append(min(df[-1]['value'][:stop_indx]))
        # print(np.argmin(df[-1]['value'][:stop_indx]))
    df = pd.concat(df, keys=keys)
    sns_plot = sns.lineplot(x="step", y="value", data=df, color=color, linewidth=linewidth, markersize=8, label=trial_id, alpha=alpha)
    return sns_plot, df_min

sns_plot, _ = plot_line(f1, keys, id1, stride=1, stop_point=stop_point, color='green', linewidth=3, alpha=1.0)
#sns_plot, _ = plot_line(f2, keys, id2, stride=1, stop_point=stop_point, color='xkcd:sky blue')
sns_plot, _ = plot_line(f5, keys, id5, stride=1, stop_point=stop_point, color='tab:cyan', linewidth=1, alpha=0.7)
#sns_plot, _ = plot_line(f7, keys, id7, stride=1, stop_point=stop_point, color='tab:pink')
sns_plot, _ = plot_line(f10, keys, id10, stride=1, stop_point=stop_point, color='tab:orange', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f20, keys, id20, stride=1, stop_point=stop_point, color='red', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f30, keys, id30, stride=1, stop_point=stop_point, color='blue', linewidth=3, alpha=1.0)
sns_plot, _ = plot_line(f40, keys, id40, stride=1, stop_point=stop_point, color='tab:purple', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f50, keys, id50, stride=1, stop_point=stop_point, color='magenta', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f60, keys, id60, stride=1, stop_point=stop_point, color='tab:brown', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f70, keys, id70, stride=1, stop_point=stop_point, color='black', linewidth=1, alpha=0.7)
sns_plot, _ = plot_line(f80, keys, id80, stride=1, stop_point=stop_point, color='tab:olive', linewidth=3, alpha=1.0)


sns_plot.set_xlabel('', fontsize = 16)
sns_plot.set_ylabel('', fontsize = 16)
sns_plot.set(yscale="log")
sns_plot.grid()
sns_plot.tick_params(axis='both', which='major', labelsize=15)
sns_plot.tick_params(axis='both', which='minor', labelsize=15)
#sns_plot.set(xscale="log", yscale="log")
sns_plot.set_xlim(right=214)
#sns_plot.set_ylim(bottom=0.002)
sns_plot.legend().set_visible(True)

fig = sns_plot.get_figure()
fig.savefig(os.path.join(save_dir, save_name))
